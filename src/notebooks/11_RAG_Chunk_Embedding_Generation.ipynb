# %% [markdown]
# Notebook 15: Chunk Embedding Generation
# Objective
# Convert chunks into vectors.
# Text
#
# ↓
#
# Embedding Model
#
# ↓
#
# Vector

# %%
# %pip install einops
# Out:
# Collecting einops
#   Downloading einops-0.8.2-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.3 MB/s eta 0:00:011
# Installing collected packages: einops
# Successfully installed einops-0.8.2
# WARNING: You are using pip version 21.2.4; however, version 26.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3.10 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# Step 1 Load Model
from sentence_transformers import SentenceTransformer

model = SentenceTransformer(
    "sentence-transformers/all-MiniLM-L6-v2", 
    device="mps"  # cuda for other computers
)
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 4259.35it/s]

# %%
#Step 2 Load Chunks
chunk_df=pd.read_csv(
"../data/processed/patent_chunks.csv"
)

# %%
#Step 3 Generate Embeddings
chunk_embeddings=model.encode(

chunk_df["chunk_text"].tolist(),

batch_size=32,

show_progress_bar=True,

normalize_embeddings=True,

convert_to_numpy=True

)
# Out:
# Batches: 100%|██████████| 23697/23697 [2:29:48<00:00,  2.64it/s]

# %%
#check:
chunk_embeddings.shape
# Out:
# (758277, 384)

# %%
import numpy as np

# Save your data
np.save("../data/processed/chunk_embeddings.npy", chunk_embeddings)
